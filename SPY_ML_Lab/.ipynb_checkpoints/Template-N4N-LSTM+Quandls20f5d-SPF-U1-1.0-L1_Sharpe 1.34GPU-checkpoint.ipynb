# %%
import matplotlib.pyplot as plt
import pandas as pd
# import talib
import numpy as np
# import lightgbm as lgb
import pyfolio as pf

# %%
#Step1 Get Original Data from Interactivebroker
filename = "quandl_N4N_5D_20071001~20200313.csv" #from IB
df = pd.read_csv(filename,index_col = 0)
# df.reset_index(drop=True,inplace=True)
print(df.shape)
print(df.head(1))
print(df.tail(1))
# Out:
# (5334, 21)
#             SPF  DJF  Oil  GOLD  USD  TBF  TN5      SPFy  SPFclose  DJFy  \
# Date
# 2000-01-04  NaN  NaN  NaN   NaN  NaN  NaN  NaN  1.030103    1411.8   NaN
#
#               ...         GOLDy  GOLDclose      Oily  Oilclose      USDy  \
# Date          ...
# 2000-01-04    ...      1.002664      281.5  1.008611     25.55  1.001598
#
#             USDclose      TBFy  TBFclose      TN5y   TN5close
# Date
# 2000-01-04     100.1  0.984828    90.625  0.993776  97.914062
#
# [1 rows x 21 columns]
#                  SPF       DJF       Oil  GOLD       USD       TBF       TN5  \
# Date
# 2020-06-12  0.008139  0.014743 -0.002201   NaN  0.005851 -0.006598 -0.000745
#
#             SPFy  SPFclose  DJFy     ...      GOLDy  GOLDclose  Oily  \
# Date                                 ...
# 2020-06-12   NaN    3034.8   NaN     ...        NaN        NaN   NaN
#
#             Oilclose  USDy  USDclose  TBFy   TBFclose  TN5y    TN5close
# Date
# 2020-06-12     36.26   NaN    97.305   NaN  178.78125   NaN  125.703125
#
# [1 rows x 21 columns]

# %%
#Step2 check data

#Check NAN
print(df.isnull().values.any() )
print("before dropping NaN", df.shape)
df.dropna(inplace=True)
print("after dropping NaN", df.shape)

# print( df.info() )
print(type(df.index[0]), df.index[0])
df.index = pd.to_datetime(df.index)
# print( df.info() )
print(type(df.index[0]), df.index[0])
# Out:
# True
# before dropping NaN (5334, 21)
# after dropping NaN (3097, 21)
# <class 'str'> 2007-10-02
# <class 'pandas._libs.tslib.Timestamp'> 2007-10-02 00:00:00

# %%
#Step Clean Data
tc=df.SPFclose #targetclose
plt.rcParams["figure.figsize"] = (20,10)
tc.plot()
print(df.head(1))
print(df.tail(1))
print(tc[0])
print(tc[-1])
# Out:
#                  SPF       DJF       Oil      GOLD       USD       TBF  \
# Date
# 2007-10-02 -0.001285 -0.003602 -0.002368 -0.015488  0.005012  0.002515
#
#                  TN5      SPFy  SPFclose      DJFy     ...        GOLDy  \
# Date                                                   ...
# 2007-10-02  0.001607  1.013894    1554.6  1.009287     ...      1.00684
#
#             GOLDclose      Oily  Oilclose      USDy  USDclose      TBFy  \
# Date
# 2007-10-02      731.0  1.002623     80.05  1.002685      78.2  0.989116
#
#             TBFclose      TN5y    TN5close
# Date
# 2007-10-02     112.0  0.993437  107.140625
#
# [1 rows x 21 columns]
#                  SPF       DJF       Oil      GOLD       USD       TBF  \
# Date
# 2020-03-06 -0.017045 -0.010399 -0.100654  0.014491 -0.008844  0.034477
#
#                  TN5      SPFy  SPFclose      DJFy     ...         GOLDy  \
# Date                                                   ...
# 2020-03-06  0.004685  0.909517    2964.1  0.891388     ...      0.928221
#
#             GOLDclose      Oily  Oilclose      USDy  USDclose     TBFy  \
# Date
# 2020-03-06    1683.65  0.768653     41.28  1.029499    95.934  0.98325
#
#              TBFclose      TN5y    TN5close
# Date
# 2020-03-06  180.96875  0.993635  123.976562
#
# [1 rows x 21 columns]
# 1554.6
# 2964.1

# %%
# NN Preprocess

# %%
# from sklearn.preprocessing import StandardScaler
# ss = StandardScaler()
# dataset_scaled = ss.fit_transform(dataset[feature_names])
# dataset_scaled = pd.DataFrame(dataset_scaled, index=dataset.index, columns=feature_names)
# dataset_scaled['return'] = dataset['return']
# dataset_scaled.describe()

# %%
print(df.head(1))
print(df.tail(1))
dataset_scaled = df
feature_names = ['SPF', 'DJF','Oil','GOLD', 'USD', 'TBF', 'TN5']#df.columns[:-2]
y_names = ['SPFy','DJFy','Oily','GOLDy','USDy','TBFy','TN5y']
print("feature_names",feature_names)
print("y_names",y_names)
# Out:
#                  SPF       DJF       Oil      GOLD       USD       TBF  \
# Date
# 2007-10-02 -0.001285 -0.003602 -0.002368 -0.015488  0.005012  0.002515
# 2007-10-03 -0.002509 -0.003828 -0.001374 -0.001026  0.003325 -0.001393
#
#                  TN5      SPFy  SPFclose      DJFy     ...         GOLDy  \
# Date                                                   ...
# 2007-10-02  0.001607  1.013894    1554.6  1.009287     ...      1.006840
# 2007-10-03 -0.001167  1.014574    1550.7  1.006405     ...      1.015063
#
#             GOLDclose      Oily  Oilclose      USDy  USDclose      TBFy  \
# Date
# 2007-10-02     731.00  1.002623     80.05  1.002685     78.20  0.989116
# 2007-10-03     730.25  1.017013     79.94  0.997961     78.46  0.989101
#
#             TBFclose      TN5y    TN5close
# Date
# 2007-10-02   112.000  0.993437  107.140625
# 2007-10-03   111.844  0.994744  107.015625
#
# [2 rows x 21 columns]
#                  SPF       DJF       Oil      GOLD       USD       TBF  \
# Date
# 2020-03-05 -0.031849 -0.033562 -0.018811  0.010811 -0.005313  0.008830
# 2020-03-06 -0.017045 -0.010399 -0.100654  0.014491 -0.008844  0.034477
#
#                  TN5      SPFy  SPFclose      DJFy     ...         GOLDy  \
# Date                                                   ...
# 2020-03-05  0.001903  0.818737    3015.5  0.809094     ...      0.946433
# 2020-03-06  0.004685  0.909517    2964.1  0.891388     ...      0.928221
#
#             GOLDclose      Oily  Oilclose      USDy  USDclose      TBFy  \
# Date
# 2020-03-05    1659.60  0.686275     45.90  1.006964    96.790  1.030368
# 2020-03-06    1683.65  0.768653     41.28  1.029499    95.934  0.983250
#
#              TBFclose      TN5y    TN5close
# Date
# 2020-03-05  174.93750  1.002026  123.398438
# 2020-03-06  180.96875  0.993635  123.976562
#
# [2 rows x 21 columns]
# feature_names ['SPF', 'DJF', 'Oil', 'GOLD', 'USD', 'TBF', 'TN5']
# y_names ['SPFy', 'DJFy', 'Oily', 'GOLDy', 'USDy', 'TBFy', 'TN5y']

# %%
import tqdm

n = 20

X = []
y = []
indexes = []
dataset_scaled_x = dataset_scaled[feature_names]
dataset_scaled_y = dataset_scaled[y_names]


print(dataset_scaled_x.head(1))
print(dataset_scaled_y.head(1))
# Out:
#                  SPF       DJF       Oil      GOLD       USD       TBF  \
# Date
# 2007-10-02 -0.001285 -0.003602 -0.002368 -0.015488  0.005012  0.002515
#
#                  TN5
# Date
# 2007-10-02  0.001607
#                 SPFy      DJFy      Oily    GOLDy      USDy      TBFy  \
# Date
# 2007-10-02  1.013894  1.009287  1.002623  1.00684  1.002685  0.989116
#
#                 TN5y
# Date
# 2007-10-02  0.993437

# %%
for i in tqdm.tqdm_notebook(range(0, len(dataset_scaled)-n)):
    X.append(dataset_scaled_x.iloc[i:i+n].values)
    y.append(dataset_scaled_y.iloc[i+n-1])
    indexes.append(dataset_scaled.index[i+n-1])
print(dataset_scaled.head())
print(dataset_scaled.tail())
# Out:
# /Users/Gene/anaconda3/envs/OM8MO/lib/python3.6/site-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# HBox(children=(FloatProgress(value=0.0, max=3077.0), HTML(value='')))
#                  SPF       DJF       Oil      GOLD       USD       TBF  \
# Date
# 2007-10-02 -0.001285 -0.003602 -0.002368 -0.015488  0.005012  0.002515
# 2007-10-03 -0.002509 -0.003828 -0.001374 -0.001026  0.003325 -0.001393
# 2007-10-04  0.000967 -0.000783  0.018764 -0.006505 -0.001020  0.002235
# 2007-10-05  0.011919  0.008190 -0.002701  0.015851 -0.001850 -0.011713
# 2007-10-09  0.008639  0.008858  0.015692  0.003066 -0.001782  0.000000
#
#                  TN5      SPFy  SPFclose      DJFy     ...         GOLDy  \
# Date                                                   ...
# 2007-10-02  0.001607  1.013894    1554.6  1.009287     ...      1.006840
# 2007-10-03 -0.001167  1.014574    1550.7  1.006405     ...      1.015063
# 2007-10-04  0.000876  1.008375    1552.2  1.003205     ...      1.032391
# 2007-10-05 -0.005106  1.002483    1570.7  1.001625     ...      1.016961
# 2007-10-09 -0.001320  0.981855    1576.2  0.981387     ...      1.028193
#
#             GOLDclose      Oily  Oilclose      USDy  USDclose      TBFy  \
# Date
# 2007-10-02     731.00  1.002623     80.05  1.002685    78.200  0.989116
# 2007-10-03     730.25  1.017013     79.94  0.997961    78.460  0.989101
# 2007-10-04     725.50  1.020138     81.44  0.995152    78.380  0.984665
# 2007-10-05     737.00  1.030411     81.22  0.999041    78.235  0.996904
# 2007-10-09     736.00  1.091577     80.26  0.997194    78.410  0.996615
#
#             TBFclose      TN5y    TN5close
# Date
# 2007-10-02   112.000  0.993437  107.140625
# 2007-10-03   111.844  0.994744  107.015625
# 2007-10-04   112.094  0.992123  107.109375
# 2007-10-05   110.781  0.998240  106.562500
# 2007-10-09   110.781  1.001615  106.421875
#
# [5 rows x 21 columns]
#                  SPF       DJF       Oil      GOLD       USD       TBF  \
# Date
# 2020-03-02  0.038630  0.043526  0.044459 -0.006336 -0.007769  0.004923
# 2020-03-03 -0.022185 -0.022216  0.009198  0.009908 -0.002024  0.006351
# 2020-03-04  0.039238  0.041924 -0.008478  0.016311  0.001905  0.000541
# 2020-03-05 -0.031849 -0.033562 -0.018811  0.010811 -0.005313  0.008830
# 2020-03-06 -0.017045 -0.010399 -0.100654  0.014491 -0.008844  0.034477
#
#                  TN5      SPFy  SPFclose      DJFy     ...         GOLDy  \
# Date                                                   ...
# 2020-03-02  0.001981  0.896447    3065.1  0.902108     ...      1.045541
# 2020-03-03  0.003699  0.956191    2997.1  0.960162     ...      1.024884
# 2020-03-04  0.001588  0.879796    3114.7  0.874281     ...      1.007248
# 2020-03-05  0.001903  0.818737    3015.5  0.809094     ...      0.946433
# 2020-03-06  0.004685  0.909517    2964.1  0.891388     ...      0.928221
#
#             GOLDclose      Oily  Oilclose      USDy  USDclose      TBFy  \
# Date
# 2020-03-02    1599.65  0.665882     46.75  0.974835    97.319  1.085465
# 2020-03-03    1615.50  0.728275     47.18  0.992453    97.122  1.043996
# 2020-03-04    1641.85  0.705002     46.78  0.991624    97.307  1.047937
# 2020-03-05    1659.60  0.686275     45.90  1.006964    96.790  1.030368
# 2020-03-06    1683.65  0.768653     41.28  1.029499    95.934  0.983250
#
#              TBFclose      TN5y    TN5close
# Date
# 2020-03-02  172.21875  1.016516  122.515625
# 2020-03-03  173.31250  1.005400  122.968750
# 2020-03-04  173.40625  1.002410  123.164062
# 2020-03-05  174.93750  1.002026  123.398438
# 2020-03-06  180.96875  0.993635  123.976562
#
# [5 rows x 21 columns]

# %%
import numpy as np
X = np.array(X)
y = np.array(y)

# %%
print(len(X))
# Out:
# 3077

# %%
indexes = np.array(indexes)

# %%
print(indexes)
# Out:
# [Timestamp('2007-10-30 00:00:00') Timestamp('2007-10-31 00:00:00')
#  Timestamp('2007-11-02 00:00:00') ... Timestamp('2020-03-03 00:00:00')
#  Timestamp('2020-03-04 00:00:00') Timestamp('2020-03-05 00:00:00')]

# %%
# LSTM Model

# %%
#LV1

# %%
import keras
#one layer lstm
model = keras.models.Sequential()
#model.add(keras.layers.Dense(100, activation="relu", input_shape=(len(feature_names),)))
# model.add(keras.layers.LSTM(100, return_sequences=True, input_shape=X[0].shape))
model.add(keras.layers.LSTM(100,input_shape=X[0].shape))
model.add(keras.layers.Dense(8))
model.add(keras.layers.Dense(7,kernel_initializer="uniform",activation='linear'))

adam = keras.optimizers.Adam(0.0005)

model.compile(optimizer=adam, loss="binary_crossentropy", metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 100)               43200
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 808
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 63
# =================================================================
# Total params: 44,071
# Trainable params: 44,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
#Without GPU,epoch 300 = Wall time: 7min 51s
# dataset_scaled_train = dataset_scaled[:'2015']

import datetime
X_train = X[indexes < datetime.datetime(2017, 1, 1)]
y_train = y[indexes < datetime.datetime(2017, 1, 1)]

get_best_model = keras.callbacks.ModelCheckpoint("N4N_lstm_1L_20f5.mdl", monitor="val_acc")
#xlen 3077
history = model.fit(
    X_train,  
    y_train > 1 , 
    batch_size=500, 
    epochs=100, 
    validation_split=0.2, 
    callbacks=[get_best_model])
# Out:
# Train on 1824 samples, validate on 456 samples
# Epoch 1/100
# 1824/1824 [==============================] - 0s 145us/step - loss: 0.6886 - accuracy: 0.5399 - val_loss: 0.6915 - val_accuracy: 0.5197
# Epoch 97/100
# 1824/1824 [==============================] - 0s 145us/step - loss: 0.6886 - accuracy: 0.5393 - val_loss: 0.6918 - val_accuracy: 0.5229
# Epoch 98/100
# 1824/1824 [==============================] - 0s 147us/step - loss: 0.6886 - accuracy: 0.5379 - val_loss: 0.6920 - val_accuracy: 0.5226
# Epoch 99/100
# 1824/1824 [==============================] - 0s 152us/step - loss: 0.6886 - accuracy: 0.5396 - val_loss: 0.6919 - val_accuracy: 0.5219
# Epoch 100/100
# 1824/1824 [==============================] - 0s 143us/step - loss: 0.6886 - accuracy: 0.5381 - val_loss: 0.6917 - val_accuracy: 0.5216
# CPU times: user 1min 17s, sys: 40.3 s, total: 1min 58s
# Wall time: 32 s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
model.load_weights("N4N_lstm_1L_20f5.mdl")

# %%
ey = model.predict(X)
ey = pd.Series(ey.swapaxes(0,1)[0], index=indexes)
ey.plot()

# %%
#
eq = tc[indexes]
returns = (eq.shift(-1) - eq)

signal = (ey > ey.quantile(0.6)).rolling(5).sum() > 0
#No Leg
# signal = signal.shift(1).fillna(False)

eq = (returns[signal]['2017':]).cumsum()
eq.plot()

# %%
eq = tc[indexes]


# eq = twii[dataset.index]
print(type(eq),eq)
# Out:
# <class 'pandas.core.series.Series'> Date
# 2007-10-30    1536.0
# 2007-10-31    1554.9
# 2007-11-02    1517.6
# 2007-11-05    1505.4
# 2007-11-06    1525.0
# 2007-11-07    1482.8
# 2007-11-08    1475.5
# 2007-11-09    1454.9
# 2007-11-13    1483.3
# 2007-11-14    1478.1
# 2007-11-15    1457.9
# 2007-11-16    1460.2
# 2007-11-19    1437.5
# 2007-11-20    1445.9
# 2007-11-21    1417.8
# 2007-11-23    1441.9
# 2007-11-26    1409.3
# 2007-11-27    1426.4
# 2007-11-28    1470.6
# 2007-11-29    1471.4
# 2007-11-30    1483.7
# 2007-12-03    1475.5
# 2007-12-04    1463.3
# 2007-12-05    1486.9
# 2007-12-06    1507.5
# 2007-12-07    1507.3
# 2007-12-10    1518.8
# 2007-12-11    1478.1
# 2007-12-12    1490.2
# 2007-12-13    1488.1
#                ...
# 2020-01-23    3326.0
# 2020-01-24    3293.5
# 2020-01-27    3239.6
# 2020-01-28    3278.3
# 2020-01-29    3272.4
# 2020-01-30    3289.7
# 2020-01-31    3224.0
# 2020-02-03    3245.6
# 2020-02-04    3299.5
# 2020-02-05    3335.0
# 2020-02-06    3345.2
# 2020-02-07    3325.5
# 2020-02-10    3353.0
# 2020-02-11    3357.6
# 2020-02-12    3380.5
# 2020-02-13    3377.4
# 2020-02-14    3380.9
# 2020-02-18    3369.3
# 2020-02-19    3387.2
# 2020-02-20    3369.2
# 2020-02-21    3339.3
# 2020-02-24    3226.3
# 2020-02-25    3132.6
# 2020-02-26    3110.2
# 2020-02-27    2956.9
# 2020-02-28    2951.1
# 2020-03-02    3065.1
# 2020-03-03    2997.1
# 2020-03-04    3114.7
# 2020-03-05    3015.5
# Name: SPFclose, Length: 3077, dtype: float64

# %%
plt.rcParams["figure.figsize"] = (20,10)


#(..)
eq = tc[indexes]


returns = (eq.shift(-1) - eq)
# print(eq[2016:][:5])
# print(ey > ey.quantile(0.9))

# print((ey > ey.quantile(0.9)).rolling(10).sum())
signalup = (ey > ey.quantile(0.6)).rolling(5).sum()>0 #r(10) S1.39 40%;r(3) S2.07 28.9%
# print(signalup["2016":][:5])
# signalup = signalup.shift(1).fillna(False) #key with 1.58-> wo 0.24!!!!
# print(signalup["2016":][:5])
signaldn = (ey < ey.quantile(0.1)).rolling(5).sum()>0 #r(10) S-0.3 r(3) S0.47
# print(signaldn[:5])
# signaldn = signaldn.shift(1).fillna(False) #with 0.49 wo -0.3
# print(signaldn[:5])
returns['2017':].cumsum().plot(c="black")
# print(len(eq))
# print(signal[:5])
# print(returns[:5])
equp = (returns[signalup]['2017':])#.cumsum()
# print(type(equp))
equp.cumsum().plot()
eqdn = (-1*returns[signaldn]['2017':])#.cumsum()
eqdn.cumsum().plot()
# print(equp[:5])
# print(eqdn[:5])
# print(len(equp))
# print(len(eqdn))



# eq=equp.add(eqdn, fill_value=0).cumsum() #r(3) r(3) S1.03; r(10) r(3) S1.04 43.5%
# eq=eqdn.add(equp, fill_value=0).cumsum() #same order
#0.6 r3 0.1 r3 -> 0.69 41.1%;
#0.9 r3 0.1 r3 -> 1.03 33%
eq=equp.cumsum()
# eq=eqdn.cumsum()

# print(len(eq))
eq.plot(c='red')
# print(equp[:10])
# print(eqdn[:10])
# print(eq2)
# print(eq)
plt.show()
print("eq",eq[-2])
# Out:
# eq 615.0700000000015

# %%
fee=signal['2017':].astype(int).diff().abs().sum()
print(fee)
print(eq[-2:])
print(eq[-2]-fee)
# Out:
# 71.0
# Date
# 2020-02-27    687.7
# 2020-02-28    801.7
# Name: SPFclose, dtype: float64
# 616.6999999999998

# %%
ey["2017":].plot()

# %%
#Benchmark
#(..)
eq_relative = eq + tc[tc.index == eq.index[0]][0]
tw_relative = tc[eq.index[0]:]

plt.rcParams["figure.figsize"] = (20,10)
eq_relative.plot(c="red",  label="LSTM strategy")
tw_relative.plot(c="blue", label="Buy & Hold")
plt.legend(loc='best')

eqpc = eq_relative.pct_change()
bmpc = tw_relative.pct_change() 
print(len(eqpc))
print(len(bmpc))
# Out:
# 479
# 798

# %%
print(eqpc)
# Out:
# Date
# 2017-01-03         NaN
# 2017-01-04    0.000000
# 2017-01-05    0.003180
# 2017-01-11   -0.003170
# 2017-01-12    0.004019
# 2017-01-13   -0.004311
# 2017-01-17    0.001723
# 2017-01-18   -0.002205
# 2017-01-19    0.001901
# 2017-01-20   -0.001720
# 2017-01-23    0.005568
# 2017-01-24    0.008482
# 2017-01-25    0.000087
# 2017-02-09    0.003660
# 2017-02-10    0.005904
# 2017-02-13    0.004618
# 2017-02-14    0.005757
# 2017-02-15   -0.002050
# 2017-02-16    0.000984
# 2017-02-17    0.005174
# 2017-02-21    0.000383
# 2017-02-22    0.000808
# 2017-02-23    0.000892
# 2017-02-24    0.001443
# 2017-02-27   -0.002331
# 2017-02-28    0.013044
# 2017-03-01   -0.004865
# 2017-03-02   -0.000295
# 2017-03-30   -0.002277
# 2017-03-31   -0.001310
#                 ...
# 2019-11-19   -0.002935
# 2019-11-20   -0.001580
# 2019-11-21    0.002390
# 2019-12-09    0.000464
# 2019-12-10    0.002197
# 2019-12-11    0.007659
# 2019-12-12    0.001257
# 2019-12-13    0.006826
# 2019-12-17    0.000882
# 2019-12-18    0.003736
# 2019-12-19    0.005629
# 2019-12-20    0.000451
# 2019-12-23   -0.000451
# 2019-12-24    0.005627
# 2019-12-26   -0.002035
# 2019-12-30    0.010674
# 2020-01-02   -0.007002
# 2020-01-03    0.002450
# 2020-01-06   -0.002474
# 2020-01-07    0.007439
# 2020-01-08    0.004656
# 2020-01-09   -0.003306
# 2020-02-19   -0.005331
# 2020-02-20   -0.008903
# 2020-02-21   -0.033949
# 2020-02-24   -0.029140
# 2020-02-25   -0.007175
# 2020-02-26   -0.049461
# 2020-02-27   -0.001969
# 2020-02-28    0.038772
# Name: SPFclose, Length: 479, dtype: float64

# %%
import pyfolio as pf 
pf.create_returns_tear_sheet( eqpc, benchmark_rets = bmpc ) #eq_relative sharpe 0.23
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-02-28</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>22</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>17.1%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>34.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.6%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.23</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.29</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-13.2%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.71</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.6%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.19</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.04</td>
#     </tr>
#   </tbody>
# </table>
# /Users/Gene/anaconda3/envs/OM8MO/lib/python3.6/site-packages/numpy/core/fromnumeric.py:61: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return bound(*args, **kwds)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>13.20</td>
#       <td>2020-01-08</td>
#       <td>2020-02-27</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>12.91</td>
#       <td>2018-08-28</td>
#       <td>2018-12-21</td>
#       <td>2019-02-04</td>
#       <td>115</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.88</td>
#       <td>2018-02-23</td>
#       <td>2018-03-29</td>
#       <td>2018-06-01</td>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.72</td>
#       <td>2019-05-02</td>
#       <td>2019-05-10</td>
#       <td>2019-06-07</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.82</td>
#       <td>2018-06-04</td>
#       <td>2018-06-26</td>
#       <td>2018-07-25</td>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Benchmark
import pyfolio as pf 
pf.create_returns_tear_sheet(  bmpc ) #eq_relative sharpe 0.23
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2017-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-03-06</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>38</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>9.1%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>31.6%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>14.2%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.68</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.44</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-20.4%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.14</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.7%</td>
#     </tr>
#   </tbody>
# </table>
# /Users/Gene/anaconda3/envs/OM8MO/lib/python3.6/site-packages/numpy/core/fromnumeric.py:61: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return bound(*args, **kwds)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20.36</td>
#       <td>2018-09-21</td>
#       <td>2018-12-24</td>
#       <td>2019-04-26</td>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>12.87</td>
#       <td>2020-02-19</td>
#       <td>2020-02-28</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10.42</td>
#       <td>2018-01-26</td>
#       <td>2018-04-02</td>
#       <td>2018-08-24</td>
#       <td>151</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6.75</td>
#       <td>2019-04-30</td>
#       <td>2019-06-03</td>
#       <td>2019-06-20</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6.43</td>
#       <td>2019-07-26</td>
#       <td>2019-08-05</td>
#       <td>2019-10-28</td>
#       <td>67</td>
#     </tr>
#   </tbody>
# </table>
